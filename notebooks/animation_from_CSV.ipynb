# %%
# Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls outputCSV
# Out:
# 0_FaceMeshLandmarks_2022_02_10-12_54_01_PM.csv
# 0_FaceMeshLandmarks_bro_2022_03_17-01_42_26_PM.csv
# 0_FaceMeshLandmarks_{date}.csv
# 0_handLandMarks_{date}.csv
# 1_handLandMarks_{date}.csv
# FULL_FaceMeshLandmarks_2022_03_17-03_51_35_PM.csv
# FULL_RIGHT_HandLandmarks_2022_03_17-04_02_28_PM.csv

# %%
df = pd.DataFrame()
df.read_csv("outputCSV)
